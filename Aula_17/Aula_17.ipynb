# %%
import pandas as pd

dados = pd.read_csv('/content/manutencao_preditiva.csv')
dados
# Out:
#         UDI ID Produto Tipo  Temperatura Ar [K]  Temperatura Processo [K]  \
# 0         1     M14860    M               298.1                     308.6
# 1         2     L47181    L               298.2                     308.7
# 2         3     L47182    L               298.1                     308.5
# 3         4     L47183    L               298.2                     308.6
# 4         5     L47184    L               298.2                     308.7
# ...     ...        ...  ...                 ...                       ...
# 9995   9996     M24855    M               298.8                     308.4
# 9996   9997     H39410    H               298.9                     308.4
# 9997   9998     M24857    M               299.0                     308.6
# 9998   9999     H39412    H               299.0                     308.7
# 9999  10000     M24859    M               299.0                     308.7
#
#       Velocidade Rotacao [rpm]  Torque [Nm]  Desgaste Ferramenta [min]  Alvo  \
# ...

# %%
map_falha = {
    "No Failure": 0,
    "Heat Dissipation Failure": 1,
    "Power Failure": 2,
    "Overstrain Failure": 3,
    "Tool Wear Failure": 4,
    "Random Failures": 5,
}

dados["Tipo da Falha Num"] = dados["Tipo da Falha"].map(map_falha)
dados
# Out:
#         UDI ID Produto Tipo  Temperatura Ar [K]  Temperatura Processo [K]  \
# 0         1     M14860    M               298.1                     308.6
# 1         2     L47181    L               298.2                     308.7
# 2         3     L47182    L               298.1                     308.5
# 3         4     L47183    L               298.2                     308.6
# 4         5     L47184    L               298.2                     308.7
# ...     ...        ...  ...                 ...                       ...
# 9995   9996     M24855    M               298.8                     308.4
# 9996   9997     H39410    H               298.9                     308.4
# 9997   9998     M24857    M               299.0                     308.6
# 9998   9999     H39412    H               299.0                     308.7
# 9999  10000     M24859    M               299.0                     308.7
#
#       Velocidade Rotacao [rpm]  Torque [Nm]  Desgaste Ferramenta [min]  Alvo  \
# ...

# %%
map_tipo = {
    "H": 0,
    "L": 1,
    "M": 2
}

dados["Tipo Num"] = dados["Tipo"].map(map_tipo)
dados
# Out:
#         UDI ID Produto Tipo  Temperatura Ar [K]  Temperatura Processo [K]  \
# 0         1     M14860    M               298.1                     308.6
# 1         2     L47181    L               298.2                     308.7
# 2         3     L47182    L               298.1                     308.5
# 3         4     L47183    L               298.2                     308.6
# 4         5     L47184    L               298.2                     308.7
# ...     ...        ...  ...                 ...                       ...
# 9995   9996     M24855    M               298.8                     308.4
# 9996   9997     H39410    H               298.9                     308.4
# 9997   9998     M24857    M               299.0                     308.6
# 9998   9999     H39412    H               299.0                     308.7
# 9999  10000     M24859    M               299.0                     308.7
#
#       Velocidade Rotacao [rpm]  Torque [Nm]  Desgaste Ferramenta [min]  Alvo  \
# ...

# %%
dados_num = dados.select_dtypes(include=['int64', 'float64'])

corr_matrix = dados_num.corr(method='pearson')

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 5))
sns.heatmap(corr_matrix, annot=True, fmt=".2f",
cmap="coolwarm",
            cbar=True, square=True)
plt.title('Matriz de Correlação de Pearson')
plt.show()

# %%
# Seleção das variáveis importantes

df_novo = dados[['Tipo Num',
                 'Temperatura Ar [K]',
                 'Temperatura Processo [K]',
                 'Velocidade Rotacao [rpm]',
                 'Torque [Nm]',
                 'Tipo da Falha Num']]

# Entradas e saída
entradas = df_novo[['Tipo Num',
                 'Temperatura Ar [K]',
                 'Temperatura Processo [K]',
                 'Velocidade Rotacao [rpm]',
                 'Torque [Nm]']]

saida = df_novo['Tipo da Falha Num']

# Preparação dos dados para treino e teste

from sklearn.model_selection import train_test_split

xtreino, xteste, ytreino, yteste = train_test_split(entradas, saida, test_size=0.3)

xtreino
# Out:
#       Tipo Num  Temperatura Ar [K]  Temperatura Processo [K]  \
# 8657         1               297.4                     308.4
# 3036         1               300.4                     309.6
# 3576         1               301.6                     310.4
# 8583         1               297.4                     308.0
# 724          1               297.5                     308.9
# ...        ...                 ...                       ...
# 6620         2               301.6                     310.7
# 5134         1               304.1                     313.3
# 5732         1               302.2                     311.7
# 4909         1               303.5                     312.4
# 3625         2               302.1                     311.4
#
#       Velocidade Rotacao [rpm]  Torque [Nm]
# 8657                      1421         46.0
# 3036                      1319         48.1
# 3576                      1599         41.7
# 8583                      1423         38.0
# ...

# %%
# Preparação dos parâmetros do modelo - rede neural MLP

from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(100), max_iter=100, activation='relu', random_state=42, verbose=True)

#n_iter_no_change=50

# Treinar o modelo utilizando os dados de treino

treino = mlp.fit(xtreino, ytreino)
treino
# Out:
# Iteration 1, loss = 1.26120976
# Iteration 2, loss = 0.70542916
# Iteration 3, loss = 0.57976378
# Iteration 4, loss = 0.79083772
# Iteration 5, loss = 0.62331551
# Iteration 6, loss = 0.55352361
# Iteration 7, loss = 0.35267555
# Iteration 8, loss = 0.34230773
# Iteration 9, loss = 0.27660186
# Iteration 10, loss = 0.27796932
# Iteration 11, loss = 0.37289106
# Iteration 12, loss = 0.27703460
# Iteration 13, loss = 0.46714709
# Iteration 14, loss = 0.81963740
# Iteration 15, loss = 0.76854143
# Iteration 16, loss = 0.78220975
# Iteration 17, loss = 0.41939649
# Iteration 18, loss = 0.23039896
# Iteration 19, loss = 0.25198238
# Iteration 20, loss = 0.62590647
# Iteration 21, loss = 1.01842170
# Iteration 22, loss = 0.66820412
# Iteration 23, loss = 0.42066443
# Iteration 24, loss = 0.67024474
# Iteration 25, loss = 0.63235457
# Iteration 26, loss = 0.37390174
# Iteration 27, loss = 0.38712199
# Iteration 28, loss = 0.33261629
# Iteration 29, loss = 0.21750228
# ...

# %%
# Avaliando o modelo

from sklearn.metrics import accuracy_score, confusion_matrix

y_pred = mlp.predict(xteste)
acuracia = accuracy_score(yteste, y_pred)
matriz_confusao = confusion_matrix(yteste, y_pred)

print("Acurácia:", acuracia)
print("Matriz de Confusão:")
print(matriz_confusao)
# Out:
# Acurácia: 0.974
# Matriz de Confusão:
# [[2895    0   10    0    0    0]
#  [  29    0    0    0    0    0]
#  [   6    0   27    0    0    0]
#  [  17    0    0    0    0    0]
#  [  13    0    0    0    0    0]
#  [   3    0    0    0    0    0]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

cm = confusion_matrix(yteste, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=np.unique(ytreino),
            yticklabels=np.unique(ytreino))

plt.xlabel('Valores Previstos')
plt.ylabel('Valores Reais')
plt.title('Matriz de Confusão')
plt.show()
